# %% [markdown]
# ProjectX
# Task: Implementing Iris Flower Classification using k-Nearest Neighbors (k-NN)

# %%
# Importing Libraries

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd

# %%
# Representation of Dataset

iris = load_iris()
df = pd.DataFrame.from_records(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
# Graphical Representation
import matplotlib.pyplot as plt

data = iris.data
target = iris.target
feature_names = iris.feature_names

plt.scatter(data[:, 0], data[:, 1], c=target)
plt.xlabel(feature_names[0])
plt.ylabel(feature_names[1])
plt.title("Scatter Plot of Iris Dataset")
plt.show()

# %%
# Dataset Shape

df.shape
# Out:
# (150, 4)

# %%
# Dataset Splitting

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

# %%
KNN = KNeighborsClassifier(n_neighbors = 3, algorithm='auto')
KNN.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
print(x_test)
prdt = KNN.predict(x_test)
print(prdt)
# Out:
# [[6.5 2.8 4.6 1.5]
#  [6.7 3.3 5.7 2.1]
#  [6.4 3.1 5.5 1.8]
#  [6.8 2.8 4.8 1.4]
#  [4.8 3.  1.4 0.3]
#  [5.  3.5 1.3 0.3]
#  [5.6 2.8 4.9 2. ]
#  [4.6 3.1 1.5 0.2]
#  [5.5 2.4 3.7 1. ]
#  [7.1 3.  5.9 2.1]
#  [5.9 3.  5.1 1.8]
#  [5.1 2.5 3.  1.1]
#  [5.5 2.3 4.  1.3]
#  [7.9 3.8 6.4 2. ]
#  [4.9 3.6 1.4 0.1]
#  [5.2 3.4 1.4 0.2]
#  [5.9 3.  4.2 1.5]
#  [5.5 4.2 1.4 0.2]
#  [5.1 3.5 1.4 0.2]
#  [4.6 3.2 1.4 0.2]
#  [6.6 3.  4.4 1.4]
#  [4.7 3.2 1.3 0.2]
#  [5.6 3.  4.5 1.5]
#  [7.3 2.9 6.3 1.8]
#  [5.  3.2 1.2 0.2]
#  [6.7 3.3 5.7 2.5]
#  [5.7 2.5 5.  2. ]
#  [6.2 2.9 4.3 1.3]
#  [5.  3.5 1.6 0.6]
#  [5.7 3.  4.2 1.2]
#  [5.4 3.4 1.7 0.2]
#  [5.  3.  1.6 0.2]
#  [4.9 2.5 4.5 1.7]
#  [5.  3.3 1.4 0.2]
#  [6.7 3.1 5.6 2.4]
#  [6.5 3.  5.8 2.2]
#  [5.4 3.  4.5 1.5]
#  [6.7 3.  5.2 2.3]
#  [5.8 2.7 5.1 1.9]
#  [7.2 3.6 6.1 2.5]
#  [5.8 2.7 4.1 1. ]
#  [6.3 2.9 5.6 1.8]
#  [7.7 3.8 6.7 2.2]
#  [6.5 3.  5.5 1.8]
#  [5.5 2.6 4.4 1.2]]
# ...

# %%
# Classifier For x_test

"""for i in x_test:
    for j in prdt:
        print(f"Iris Data: {i}\n Prediction: {j}")"""
        
        
targetNames = load_iris().target_names
for data in x_test:
    prediction = KNN.predict([data])
    print(f"Iris Data: {data}\n Prediction: {targetNames[prediction[0]]}\n\n")
# Out:
# Iris Data: [6.5 2.8 4.6 1.5]
#  Prediction: versicolor
#
#
# Iris Data: [6.7 3.3 5.7 2.1]
#  Prediction: virginica
#
#
# Iris Data: [6.4 3.1 5.5 1.8]
#  Prediction: virginica
#
#
# Iris Data: [6.8 2.8 4.8 1.4]
#  Prediction: versicolor
#
#
# Iris Data: [4.8 3.  1.4 0.3]
#  Prediction: setosa
#
#
# Iris Data: [5.  3.5 1.3 0.3]
#  Prediction: setosa
#
#
# Iris Data: [5.6 2.8 4.9 2. ]
#  Prediction: virginica
#
#
# Iris Data: [4.6 3.1 1.5 0.2]
#  Prediction: setosa
#
#
# Iris Data: [5.5 2.4 3.7 1. ]
#  Prediction: versicolor
#
#
# Iris Data: [7.1 3.  5.9 2.1]
#  Prediction: virginica
#
#
# Iris Data: [5.9 3.  5.1 1.8]
#  Prediction: virginica
#
#
# Iris Data: [5.1 2.5 3.  1.1]
#  Prediction: versicolor
#
#
# Iris Data: [5.5 2.3 4.  1.3]
#  Prediction: versicolor
#
#
# Iris Data: [7.9 3.8 6.4 2. ]
#  Prediction: virginica
#
#
# Iris Data: [4.9 3.6 1.4 0.1]
#  Prediction: setosa
#
#
# Iris Data: [5.2 3.4 1.4 0.2]
#  Prediction: setosa
#
#
# Iris Data: [5.9 3.  4.2 1.5]
# ...

# %%
# Model Accuracy

accuracy = accuracy_score(y_test, prdt)
print(f"Model Accuracy: {accuracy:.3f}\nPercentage: {accuracy*100:.2f}")
# Out:
# Model Accuracy: 0.978
# Percentage: 97.78
